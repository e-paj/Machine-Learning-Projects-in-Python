# %% [markdown]
# # Web Scraping Wikipedia

# %% [markdown]
# ## Import Libraries

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %% [markdown]
# ## The Function that will do the web scraping

# %%
## get the URL of the wikipedia we want to scrape:

URL = input("Please copy and paste the URL of the group discrography you want to scrape: ")
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
# Out:
# Please copy and paste the URL of the group discrography you want to scrape: https://en.wikipedia.org/wiki/Red_Velvet_discography

# %% [markdown]
# This includes Albums: Studio, Reissue, and Compilation Albums. Also, Extended Plays. Singles, Soundtrack Appearances, etc. does not include.

# %%
data = []

for table in soup.findAll('table', attrs={'class':'wikitable plainrowheaders'}):
    table_body = table.find('tbody')
    rows = table_body.findAll('tr')
    for row in rows:
        cols = [d.get_text(strip=True) for d in row.select('th, td')]
        data.append(cols)

# %%
data
# Out:
# [['Title', 'Details', 'Peak chart positions', 'Sales'],
#  ['KOR[1]',
#   'FRADig.[2]',
#   'JPN[3]',
#   'JPN Hot[4]',
#   'US Heat.[5]',
#   'US World[6]'],
#  ['Korean'],
#  ['The Red',
#   'Released: September 9, 2015[7]Label:SM EntertainmentFormats:CD,digital download,streaming',
#   '1',
#   '—',
#   '47',
#   '—',
#   '24',
#   '1',
#   'KOR: 79,838[8]JPN: 4,478[9]US: 3,000[10]'],
#  ['Perfect Velvet',
#   'Released: November 17, 2017Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '2',
#   '95',
#   '20',
#   '52',
#   '3',
#   '1',
#   'KOR: 117,759[11]JPN: 12,799[A][12]US: 3,000[13]'],
#  ['Japanese'],
#  ['Bloom',
#   'Scheduled: February 2, 2022Label:Avex Trax,SM Entertainment JapanFormats: CD, digital download, streaming',
#   'TBA',
#   'TBA'],
#  ['"—" denotes releases that did not chart or were not released in that region.'],
#  ['Title', 'Details', 'Peak chart positions', 'Sales'],
#  ['KOR[1]',
#   'FRA Dig.[14]',
#   'JPN[15]',
#   'JPN Hot[16]',
#   'US Heat.[5]',
#   'US World[6]'],
#  ['The Perfect Red Velvet',
#   'Released: January 29, 2018Label: SM EntertainmentFormats: CD, digital download, streaming,SMC',
#   '1',
#   '87',
#   '29',
#   '49',
#   '7',
#   '3',
#   'KOR: 120,957[17]JPN: 12,799[A][12]'],
#  ['Title', 'Details', 'Peak chart positions', 'Sales'],
#  ['KOR[1]', 'JPN[18]', 'JPN Hot[19]', 'US Heat.[5]', 'US World[6]'],
#  ['The ReVe Festival: Finale',
#   'Released: December 23, 2019Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '1',
#   '24',
#   '45',
#   '2',
#   '3',
#   'KOR: 194,290[20]JPN: 7,442(Phy.)[21]JPN: 590(Dig.)[22]'],
#  ['Title', 'Details', 'Peak chart positions', 'Sales', 'Certifications[B]'],
#  ['KOR[23]',
#   'AUS Dig.[24][C]',
#   'FRADig.[25]',
#   'JPN[26]',
#   'JPN Hot[27]',
#   'UK Down.[28]',
#   'US Heat[5]',
#   'US World[6]'],
#  ['Korean'],
#  ['Ice Cream Cake',
#   'Released: March 18, 2015Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '1',
#   '—',
#   '—',
#   '76',
#   '—',
#   '—',
#   '24',
#   '2',
#   'KOR: 90,970[29]JPN: 2,796[30]US: 3,000[10]',
#   'N/A'],
#  ['The Velvet',
#   'Released: March 17, 2016Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '1',
#   '—',
#   '—',
#   '75',
#   '—',
#   '—',
#   '—',
#   '8',
#   'KOR: 56,944[31]JPN: 2,104[32]'],
#  ['Russian Roulette',
#   'Released: September 7, 2016Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '1',
#   '—',
#   '174',
#   '40',
#   '—',
#   '—',
#   '18',
#   '2',
#   'KOR: 87,693[33]JPN: 3,446[34]US: 2,000[10]'],
#  ['Rookie',
#   'Released: February 1, 2017Label: SM EntertainmentFormats: CD, digital download, streaming, SMC',
#   '1',
#   '—',
#   '—',
#   '43',
#   '—',
#   '—',
#   '21',
#   '1',
#   'KOR: 118,747[35]JPN: 4,351[36]'],
#  ['The Red Summer',
#   'Released: July 10, 2017Label: SM EntertainmentFormats: CD, digital download, streaming, SMC',
#   '1',
#   '—',
#   '108',
#   '27',
#   '—',
#   '—',
#   '8',
#   '1',
#   'KOR: 110,705[37]JPN: 4,659[38]US: 2,000[39]'],
#  ['Summer Magic',
#   'Released: August 6, 2018Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '1',
#   '31',
#   '42',
#   '12',
#   '24',
#   '38',
#   '3',
#   '3',
#   'KOR: 174,531[40]JPN: 8,004(Phy.)[41]JPN: 946(Dig.)[42]US: 2,000[43]',
#   ''],
#  ['RBB',
#   'Released: November 30, 2018Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '3',
#   '—',
#   '92',
#   '33',
#   '51',
#   '60',
#   '1',
#   '2',
#   'KOR: 108,796[44]JPN: 5,411[45]US: 10,000[46]',
#   ''],
#  ['The ReVe Festival: Day 1',
#   'Released: June 19, 2019Label: SM EntertainmentFormats: CD, digital download, streaming, SMC',
#   '1',
#   '—',
#   '53',
#   '20',
#   '46',
#   '68',
#   '5',
#   '7',
#   'KOR: 193,669[47]JPN: 4,855[48]',
#   ''],
#  ['The ReVe Festival: Day 2',
#   'Released: August 20, 2019Label: SM EntertainmentFormats: CD, digital download, streaming, SMC',
#   '1',
#   '—',
#   '52',
#   '17',
#   '54',
#   '51',
#   '11',
#   '6',
#   'KOR: 140,537[49]JPN: 3,960(Phy.)[50]JPN: 427(Dig.)[51]US: 1,000[52]',
#   ''],
#  ['Queendom',
#   'Released: August 16, 2021Label: SM EntertainmentFormats: CD, digital download, streaming',
#   '2',
#   '—',
#   '—',
#   '11',
#   '23',
#   '17',
#   '16',
#   '11',
#   'KOR: 360,070[53]JPN: 12,452(Phy.)[54]',
#   'KMCA: Platinum[55]'],
#  ['Japanese'],
#  ['#Cookie Jar',
#   'Released: July 4, 2018Label: Avex Trax, SM Entertainment JapanFormats: CD, digital download, streaming',
#   '—',
#   '—',
#   '—',
#   '3',
#   '4',
#   '—',
#   '—',
#   '13',
#   'JPN: 31,638[56]',
#   ''],
#  ['Sappy',
#   'Released: May 29, 2019Label: Avex Trax, SM Entertainment JapanFormats: CD, DVD, digital download, streaming',
#   '—',
#   '—',
#   '—',
#   '4',
#   '4',
#   '—',
#   '—',
#   '—',
#   'JPN: 17,236[57]',
#   ''],
#  ['"—" denotes releases that did not chart or were not released in that region.'],
#  ['Title',
#   'Year',
#   'Peak chart positions',
#   'Sales(DL)',
#   'Certifications',
#   'Album'],
#  ['KOR', 'CAN[58]', 'JPN Hot[59]', 'NZHot[60]', 'SGP[61]', 'US World[62]'],
#  ['Gaon[63]', 'Hot[64]'],
#  ['Korean'],
#  ['"Happiness"(행복)',
#   '2014',
#   '5',
#   'N/A',
#   '—',
#   '—',
#   '—',
#   '—',
#   '4',
#   'KOR: 433,336[65]US: 15,000[10]',
#   'N/A',
#   'Non-album singles'],
#  ['"Be Natural"', '33', '—', '—', '—', '—', '6', 'KOR: 70,920[66]'],
#  ['"Automatic"',
#   '2015',
#   '32',
#   '—',
#   '—',
#   '—',
#   '—',
#   '9',
#   'KOR: 80,662[67]',
#   'Ice Cream Cake'],
#  ['"Ice Cream Cake"',
#   '4',
#   '—',
#   '—',
#   '—',
#   '—',
#   '3',
#   'KOR: 1,378,831[68]US: 23,000[10][69]'],
#  ['"Dumb Dumb"',
#   '2',
#   '—',
#   '—',
#   '—',
#   '—',
#   '3',
#   'KOR: 1,611,205[68]US: 26,000[10][69]',
#   'The Red'],
#  ['"Wish Tree"(세가지 소원)',
#   '33',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'KOR: 128,382[70]',
#   'Winter Garden'],
#  ['"One of These Nights"(7월 7일)',
#   '2016',
#   '10',
#   '—',
#   '—',
#   '—',
#   '—',
#   '6',
#   'KOR: 365,450[71]',
#   'The Velvet'],
#  ['"Russian Roulette"(러시안 룰렛)',
#   '2',
#   '70',
#   '—',
#   '—',
#   '—',
#   '—',
#   '2',
#   'KOR: 2,500,000[72]US: 24,000[10][69]',
#   'Russian Roulette'],
#  ['"Rookie"',
#   '2017',
#   '3',
#   '39',
#   '—',
#   '—',
#   '—',
#   '—',
#   '4',
#   'KOR: 1,358,020[73]',
#   'Rookie'],
#  ['"Would U"',
#   '13',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   'KOR: 188,236[74]',
#   'SM Station Season 2'],
#  ['"Red Flavor"(빨간 맛)',
#   '1',
#   '2',
#   '—',
#   '25',
#   '—',
#   '—',
#   '4',
#   'KOR: 2,500,000[75]',
#   'The Red Summer'],
#  ['"Rebirth"(환생)',
#   '78',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '25',
#   'KOR: 51,816[76]',
#   'SM Station Season 2'],
#  ['"Peek-a-Boo"(피카부)',
#   '2',
#   '2',
#   '—',
#   '36',
#   '—',
#   '—',
#   '2',
#   'KOR: 2,500,000[77]US: 21,000[10][69]',
#   'Perfect Velvet'],
#  ['"Bad Boy"',
#   '2018',
#   '2',
#   '2',
#   '87',
#   '49',
#   '—',
#   '8',
#   '2',
#   'KOR: 2,500,000[78]US: 27,000[46][69]',
#   'KMCA: Platinum(DL)[79]',
#   'The Perfect Red Velvet'],
#  ['"Power Up"',
#   '1',
#   '1',
#   '—',
#   '—[D]',
#   '—',
#   '—[E]',
#   '6',
#   'KOR: 1,201,030[83]US: 1,000[43]',
#   '',
#   'Summer Magic'],
#  ['"RBB (Really Bad Boy)"',
#   '10',
#   '7',
#   '—',
#   '93',
#   '—',
#   '14',
#   '1',
#   'US: 2,000[84]',
#   '',
#   'RBB'],
#  ['"Close to Me"(Red Velvet remix)(withEllie GouldingandDiplo)[85]',
#   '2019',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '',
#   '',
#   'Brightest Blue'],
#  ['"Zimzalabim"(짐살라빔)',
#   '11',
#   '4',
#   '—',
#   '—',
#   '39',
#   '—',
#   '10',
#   '',
#   '',
#   'The ReVe Festival: Day 1'],
#  ['"Umpah Umpah"(음파음파)',
#   '18',
#   '1',
#   '—',
#   '—',
#   '—',
#   '—',
#   '9',
#   '',
#   '',
#   'The ReVe Festival: Day 2'],
#  ['"Psycho"',
#   '2',
#   '2',
#   '—',
#   '—[F]',
#   '10',
#   '1',
#   '1',
#   'US: 2,000[69]',
#   'KMCA: Platinum(st.)[87]',
#   'The ReVe Festival: Finale'],
#  ['"Queendom"',
#   '2021',
#   '5',
#   '7',
#   '—',
#   '77',
#   '—',
#   '12',
#   '10',
#   '',
#   '',
#   'Queendom'],
#  ['Japanese'],
#  ['"#Cookie Jar"',
#   '2018',
#   '—[G]',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '20',
#   '',
#   '',
#   '#Cookie Jar'],
#  ['"Sappy"', '2019', '—', '—', '—', '—', '—', '—', '13', '', '', 'Sappy'],
#  ['"Sayonara"', '—', '—', '—', '—', '—', '—', '—', '', ''],
#  ['"Wildside"', '2022', 'TBA', 'Bloom'],
#  ['"—" denotes releases that did not chart or were not released in that region.'],
#  ['Title', 'Year', 'Peak chartpositions', 'Album'],
#  ['KOR'],
#  ['Gaon', 'Hot[89]'],
#  ['"Milky Way"', '2020', '119', '64', 'SM Station'],
#  ['Title', 'Year', 'Peak chartpositions', 'Album'],
#  ['KOR', 'USWorld[90]'],
#  ['Gaon[91]', 'Hot[92]'],
#  ['"Goodbye"(안녕)[H]',
#   '2015',
#   '—',
#   '—',
#   '—',
#   'Immortal Songs: Singing the Legend'],
#  ['"To Get What Your Heart Wants"(너에게 원한건)',
#   '2016',
#   '—',
#   '—',
#   '—',
#   'Two Yoo Project Sugar Man'],
#  ['"Yossism"(여시주의)', '—', '—', '—', 'Telemonster'],
#  ['"I Will Leave"(떠날 거야)',
#   '2018',
#   '—[I]',
#   '—',
#   '—',
#   'Two Yoo Project Sugar Man'],
#  ['"See the Stars"(어떤 별보다)', '2019', '50', '50', '—', 'Hotel del Luna'],
#  ['"Just Sing (Trolls World Tour)"(with various artists)',
#   '2020',
#   '—',
#   '—',
#   '—',
#   'Trolls World Tour'],
#  ['"Future"(미래)', '180', '95', '21', 'Start-Up'],
#  ['"—" denotes a recording that did not chart or was not released in that territory'],
#  ['Title', 'Year', 'Peak chart positions', 'Sales(DL)', 'Album'],
#  ['KOR', 'USWorld[96]'],
#  ['Gaon[97]', 'Hot[98]'],
#  ['"Somethin Kinda Crazy"',
#   '2015',
#   '52',
#   'N/A',
#   '—',
#   'KOR: 51,549[99]',
#   'Ice Cream Cake'],
#  ['"Stupid Cupid"', '74', '—', 'KOR: 39,575[100]'],
#  ['"Take It Slow"', '64', '—', 'KOR: 44,026[99]'],
#  ['"Candy"(사탕)', '66', '—', 'KOR: 43,693[99]'],
#  ['"Huff n Puff"', '36', '—', 'KOR: 100,944[101]', 'The Red'],
#  ['"Campfire"', '68', '—', 'KOR: 51,577[102]'],
#  ['"Red Dress"', '78', '—', 'KOR: 44,339[102]'],
#  ['"Oh Boy"', '35', '—', 'KOR: 108,422[103]'],
#  ['"Lady\'s Room"', '83', '—', 'KOR: 46,356[102]'],
#  ['"Time Slip"', '88', '—', 'KOR: 45,627[102]'],
#  ['"Don\'t U Wait No More"', '69', '—', 'KOR: 52,691[102]'],
#  ['"Day 1"', '74', '—', 'KOR: 52,264[102]'],
#  ['"Cool World"', '95', '—', 'KOR: 40,474[102]'],
#  ['"Cool Hot Sweet Love"',
#   '2016',
#   '48',
#   '23',
#   'KOR: 72,559[104]',
#   'The Velvet'],
#  ['"Light Me Up"', '79', '—', 'KOR: 48,893[104]'],
#  ['"First Time"(처음인가요)', '70', '—', 'KOR: 54,292[104]'],
#  ['"Rose Scent Breeze"(장미꽃 향기는 바람에 날리고)', '61', '—', 'KOR: 57,394[104]'],
#  ['"Lucky Girl"', '42', '—', 'KOR: 90,351[105]', 'Russian Roulette'],
#  ['"Bad Dracula"', '81', '—', 'KOR: 44,648[106]'],
#  ['"Sunny Afternoon"', '78', '—', 'KOR: 46,813[106]'],
#  ['"Fool"', '84', '—', 'KOR: 42,507[106]'],
#  ['"Some Love"', '100', '—', 'KOR: 41,246[106]'],
#  ['"My Dear"', '89', '—', 'KOR: 48,708[106]'],
#  ['"Little Little"', '2017', '41', '—', 'KOR: 75,539[107]', 'Rookie'],
#  ['"Happily Ever After"', '71', '—', 'KOR: 32,198[108]'],
#  ['"Talk to Me"', '67', '—', 'KOR: 35,861[108]'],
#  ['"Body Talk"', '79', '—', 'KOR: 28,698[108]'],
#  ['"Last Love"(마지막 사랑)', '72', '—', 'KOR: 32,656[108]'],
#  ['"You Better Know"', '14', '21', '—', 'KOR: 118,309[109]', 'The Red Summer'],
#  ['"Zoo"', '24', '30', '—', 'KOR: 82,388[110]'],
#  ['"Mojito"(여름빛)', '32', '69', '—', 'KOR: 55,235[110]'],
#  ['"Hear the Sea"(바다가 들려)', '35', '70', '—', 'KOR: 52,988[110]'],
#  ['"Look"(봐)', '74', '61', '—', 'KOR: 49,319[111]', 'Perfect Velvet'],
#  ['"I Just"', '—[J]', '—', '—', 'KOR: 23,094[112]'],
#  ['"Kingdom Come"', '—[K]', '65', '—', 'KOR: 38,855[111]'],
#  ['"My Second Date"(두 번째 데이트)', '—[L]', '67', '—', 'KOR: 37,984[111]'],
#  ['"Attaboy"', '—[M]', '—', '—', 'KOR: 20,307[112]'],
#  ['"Perfect 10"', '—[N]', '—', '—', 'KOR: 20,491[112]'],
#  ['"About Love"', '—[O]', '—', '—', 'KOR: 23,172[112]'],
#  ['"Moonlight Melody"(달빛 소리)', '98', '64', '—', 'KOR: 35,962[111]'],
#  ['"All Right"', '2018', '79', '41', '—', 'N/A', 'The Perfect Red Velvet'],
#  ['"Time To Love"', '—[P]', '—', '—'],
#  ['"With You"(한 여름의 크리스마스)', '34', '18', '—', 'Summer Magic'],
#  ['"Mr. E"', '80', '26', '—'],
#  ['"Mosquito"', '88', '29', '—'],
#  ['"Hit That Drum"', '83', '27', '—'],
#  ['"Blue Lemonade"', '68', '23', '—'],
#  ['"Bad Boy (English Version) [Bonus Track]"', '—[Q]', '—', '—'],
#  ['"Butterflies"', '—[R]', '—', '—', 'RBB'],
#  ['"So Good"', '—[S]', '—', '—'],
#  ['"Sunny Side Up!"', '2019', '123', '—', '—', 'The ReVe Festival: Day 1'],
#  ['"Milkshake"', '181', '—', '—'],
#  ['"Bing Bing"(친구가 아냐)', '—[T]', '—', '—'],
#  ['"Parade"(안녕, 여름)', '184', '—', '—'],
#  ['"LP"', '—[U]', '—', '—'],
#  ['"Carpool"(카풀)', '169', '—', '—', 'The ReVe Festival: Day 2'],
#  ['"Love Is the Way"', '199', '—', '—'],
#  ['"Jumpin\'"', '—[V]', '—', '—'],
#  ['"Ladies Night"', '—[W]', '—', '—'],
#  ['"Eyes Locked, Hands Locked"(눈 맞추고, 손 맞대고)', '—[X]', '—', '—'],
#  ['"In & Out"', '88', '50', '—', 'The ReVe Festival: Finale'],
#  ['"Remember Forever"', '128', '65', '—'],
#  ['"La Rouge (Special Track)"', '—[Y]', '—', '—'],
#  ['"Pose"', '2021', '105', '81', '—', 'Queendom'],
#  ['"Knock on Wood"', '112', '—', '—'],
#  ['"Hello, Sunset"(다시 여름)', '137', '—', '—'],
#  ['"Better Be"', '138', '—', '—'],
#  ['"Pushin\' N Pullin\'"', '139', '—', '—'],
#  ['"Queendom (Demicat Remix)"', '—[Z]', '—', '—', 'Non-album single'],
#  ['"Bad Boy (PREP Remix)"',
#   '—[AA]',
#   '—',
#   '—',
#   'iScreaM Vol. 12\xa0: Bad Boy Remixes'],
#  ['"—" denotes releases that did not chart or were not released in that region.']]

# %%
# Obtain information from range (0, 27) 
# These only includes the album and the extended plays.

data_1 = data[0:30]
print(data_1)
# Out:
# [['Title', 'Details', 'Peak chart positions', 'Sales'], ['KOR[1]', 'FRADig.[2]', 'JPN[3]', 'JPN Hot[4]', 'US Heat.[5]', 'US World[6]'], ['Korean'], ['The Red', 'Released: September 9, 2015[7]Label:SM EntertainmentFormats:CD,digital download,streaming', '1', '—', '47', '—', '24', '1', 'KOR: 79,838[8]JPN: 4,478[9]US: 3,000[10]'], ['Perfect Velvet', 'Released: November 17, 2017Label: SM EntertainmentFormats: CD, digital download, streaming', '2', '95', '20', '52', '3', '1', 'KOR: 117,759[11]JPN: 12,799[A][12]US: 3,000[13]'], ['Japanese'], ['Bloom', 'Scheduled: February 2, 2022Label:Avex Trax,SM Entertainment JapanFormats: CD, digital download, streaming', 'TBA', 'TBA'], ['"—" denotes releases that did not chart or were not released in that region.'], ['Title', 'Details', 'Peak chart positions', 'Sales'], ['KOR[1]', 'FRA Dig.[14]', 'JPN[15]', 'JPN Hot[16]', 'US Heat.[5]', 'US World[6]'], ['The Perfect Red Velvet', 'Released: January 29, 2018Label: SM EntertainmentFormats: CD, digital download, streaming,SMC', '1', '87', '29', '49', '7', '3', 'KOR: 120,957[17]JPN: 12,799[A][12]'], ['Title', 'Details', 'Peak chart positions', 'Sales'], ['KOR[1]', 'JPN[18]', 'JPN Hot[19]', 'US Heat.[5]', 'US World[6]'], ['The ReVe Festival: Finale', 'Released: December 23, 2019Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '24', '45', '2', '3', 'KOR: 194,290[20]JPN: 7,442(Phy.)[21]JPN: 590(Dig.)[22]'], ['Title', 'Details', 'Peak chart positions', 'Sales', 'Certifications[B]'], ['KOR[23]', 'AUS Dig.[24][C]', 'FRADig.[25]', 'JPN[26]', 'JPN Hot[27]', 'UK Down.[28]', 'US Heat[5]', 'US World[6]'], ['Korean'], ['Ice Cream Cake', 'Released: March 18, 2015Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '—', '—', '76', '—', '—', '24', '2', 'KOR: 90,970[29]JPN: 2,796[30]US: 3,000[10]', 'N/A'], ['The Velvet', 'Released: March 17, 2016Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '—', '—', '75', '—', '—', '—', '8', 'KOR: 56,944[31]JPN: 2,104[32]'], ['Russian Roulette', 'Released: September 7, 2016Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '—', '174', '40', '—', '—', '18', '2', 'KOR: 87,693[33]JPN: 3,446[34]US: 2,000[10]'], ['Rookie', 'Released: February 1, 2017Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '—', '43', '—', '—', '21', '1', 'KOR: 118,747[35]JPN: 4,351[36]'], ['The Red Summer', 'Released: July 10, 2017Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '108', '27', '—', '—', '8', '1', 'KOR: 110,705[37]JPN: 4,659[38]US: 2,000[39]'], ['Summer Magic', 'Released: August 6, 2018Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '31', '42', '12', '24', '38', '3', '3', 'KOR: 174,531[40]JPN: 8,004(Phy.)[41]JPN: 946(Dig.)[42]US: 2,000[43]', ''], ['RBB', 'Released: November 30, 2018Label: SM EntertainmentFormats: CD, digital download, streaming', '3', '—', '92', '33', '51', '60', '1', '2', 'KOR: 108,796[44]JPN: 5,411[45]US: 10,000[46]', ''], ['The ReVe Festival: Day 1', 'Released: June 19, 2019Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '53', '20', '46', '68', '5', '7', 'KOR: 193,669[47]JPN: 4,855[48]', ''], ['The ReVe Festival: Day 2', 'Released: August 20, 2019Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '52', '17', '54', '51', '11', '6', 'KOR: 140,537[49]JPN: 3,960(Phy.)[50]JPN: 427(Dig.)[51]US: 1,000[52]', ''], ['Queendom', 'Released: August 16, 2021Label: SM EntertainmentFormats: CD, digital download, streaming', '2', '—', '—', '11', '23', '17', '16', '11', 'KOR: 360,070[53]JPN: 12,452(Phy.)[54]', 'KMCA: Platinum[55]'], ['Japanese'], ['#Cookie Jar', 'Released: July 4, 2018Label: Avex Trax, SM Entertainment JapanFormats: CD, digital download, streaming', '—', '—', '—', '3', '4', '—', '—', '13', 'JPN: 31,638[56]', ''], ['Sappy', 'Released: May 29, 2019Label: Avex Trax, SM Entertainment JapanFormats: CD, D ...

# %%
for a in range(len(data_1)):
    if len(data_1[a]) == 1:
        data_1.pop(a)

# %% [markdown]
# Now I want to create several dataframes
#
# One for each album and one for extended plays

# %% [markdown]
# ### Album Dataframe

# %%
def column_values(a,b):
    titles = []
    details = []
    sales = []
    
    for i in range(a,b):
        if len(data_1[i]) <= 11:
            titles.append(data_1[i][0])
            details.append(data_1[i][1])
            sales.append(data_1[i][-1])
        else:
            titles.append(data_1[i][0])
            details.append(data_1[i][1])
            sales.append(data_1[i][-2])
        
    return titles, details, sales

# %%
for i in range(0, 25):
    print(i)
    print(data_1[i])
# Out:
# 0
# ['Title', 'Details', 'Peak chart positions', 'Sales']
# 1
# ['KOR[1]', 'FRADig.[2]', 'JPN[3]', 'JPN Hot[4]', 'US Heat.[5]', 'US World[6]']
# 2
# ['The Red', 'Released: September 9, 2015[7]Label:SM EntertainmentFormats:CD,digital download,streaming', '1', '—', '47', '—', '24', '1', 'KOR: 79,838[8]JPN: 4,478[9]US: 3,000[10]']
# 3
# ['Perfect Velvet', 'Released: November 17, 2017Label: SM EntertainmentFormats: CD, digital download, streaming', '2', '95', '20', '52', '3', '1', 'KOR: 117,759[11]JPN: 12,799[A][12]US: 3,000[13]']
# 4
# ['Bloom', 'Scheduled: February 2, 2022Label:Avex Trax,SM Entertainment JapanFormats: CD, digital download, streaming', 'TBA', 'TBA']
# 5
# ['Title', 'Details', 'Peak chart positions', 'Sales']
# 6
# ['KOR[1]', 'FRA Dig.[14]', 'JPN[15]', 'JPN Hot[16]', 'US Heat.[5]', 'US World[6]']
# 7
# ['The Perfect Red Velvet', 'Released: January 29, 2018Label: SM EntertainmentFormats: CD, digital download, streaming,SMC', '1', '87', '29', '49', '7', '3', 'KOR: 120,957[17]JPN: 12,799[A][12]']
# 8
# ['Title', 'Details', 'Peak chart positions', 'Sales']
# 9
# ['KOR[1]', 'JPN[18]', 'JPN Hot[19]', 'US Heat.[5]', 'US World[6]']
# 10
# ['The ReVe Festival: Finale', 'Released: December 23, 2019Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '24', '45', '2', '3', 'KOR: 194,290[20]JPN: 7,442(Phy.)[21]JPN: 590(Dig.)[22]']
# 11
# ['Title', 'Details', 'Peak chart positions', 'Sales', 'Certifications[B]']
# 12
# ['KOR[23]', 'AUS Dig.[24][C]', 'FRADig.[25]', 'JPN[26]', 'JPN Hot[27]', 'UK Down.[28]', 'US Heat[5]', 'US World[6]']
# 13
# ['Ice Cream Cake', 'Released: March 18, 2015Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '—', '—', '76', '—', '—', '24', '2', 'KOR: 90,970[29]JPN: 2,796[30]US: 3,000[10]', 'N/A']
# 14
# ['The Velvet', 'Released: March 17, 2016Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '—', '—', '75', '—', '—', '—', '8', 'KOR: 56,944[31]JPN: 2,104[32]']
# 15
# ['Russian Roulette', 'Released: September 7, 2016Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '—', '174', '40', '—', '—', '18', '2', 'KOR: 87,693[33]JPN: 3,446[34]US: 2,000[10]']
# 16
# ['Rookie', 'Released: February 1, 2017Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '—', '43', '—', '—', '21', '1', 'KOR: 118,747[35]JPN: 4,351[36]']
# 17
# ['The Red Summer', 'Released: July 10, 2017Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '108', '27', '—', '—', '8', '1', 'KOR: 110,705[37]JPN: 4,659[38]US: 2,000[39]']
# 18
# ['Summer Magic', 'Released: August 6, 2018Label: SM EntertainmentFormats: CD, digital download, streaming', '1', '31', '42', '12', '24', '38', '3', '3', 'KOR: 174,531[40]JPN: 8,004(Phy.)[41]JPN: 946(Dig.)[42]US: 2,000[43]', '']
# 19
# ['RBB', 'Released: November 30, 2018Label: SM EntertainmentFormats: CD, digital download, streaming', '3', '—', '92', '33', '51', '60', '1', '2', 'KOR: 108,796[44]JPN: 5,411[45]US: 10,000[46]', '']
# 20
# ['The ReVe Festival: Day 1', 'Released: June 19, 2019Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '53', '20', '46', '68', '5', '7', 'KOR: 193,669[47]JPN: 4,855[48]', '']
# 21
# ['The ReVe Festival: Day 2', 'Released: August 20, 2019Label: SM EntertainmentFormats: CD, digital download, streaming, SMC', '1', '—', '52', '17', '54', '51', '11', '6', 'KOR: 140,537[49]JPN: 3,960(Phy.)[50]JPN: 427(Dig.)[51]US: 1,000[52]', '']
# 22
# ['Queendom', 'Released: August 16, 2021Label: SM EntertainmentFormats: CD, digital download, streaming', '2', '—', '—', '11', '23', '17', '16', '11', 'KOR: 360,070[53]JPN: 12,452(Phy.)[54]', 'KMCA: Platinum[55]']
# 23
# ['#Cookie Jar', 'Released: July 4, 2018Label: Avex Trax, SM Entertainment JapanFormats: CD, digital download, streaming', '—', '—', '—', '3', '4', '—', '—', '13', 'JPN: 31,638[56]', '']
# 24
# ['Sappy', 'Released: May 29, 2019Label: Avex Trax, SM Entertainment JapanFormats: CD, DVD, digital download, streaming', '—', '—', '—', '4', '4', '—', '—', '—', 'JPN: 17,236[57]', '']

# %%
# Start with Studio Albums

title, detail, sale = column_values(2,5)

studio_album = pd.DataFrame(list(zip(title, detail, sale)), columns=['Title', 'Details', 'Sales'])
studio_album
# Out:
#             Title                                            Details  \
# 0         The Red  Released: September 9, 2015[7]Label:SM Enterta...
# 1  Perfect Velvet  Released: November 17, 2017Label: SM Entertain...
# 2           Bloom  Scheduled: February 2, 2022Label:Avex Trax,SM ...
#
#                                              Sales
# 0         KOR: 79,838[8]JPN: 4,478[9]US: 3,000[10]
# 1  KOR: 117,759[11]JPN: 12,799[A][12]US: 3,000[13]
# 2                                              TBA

# %%
# Reissue Albums

title, detail, sale = column_values(7,8)

reissue_album = pd.DataFrame(list(zip(title, detail, sale)), columns=['Title', 'Details', 'Sales'])
reissue_album
# Out:
#                     Title                                            Details  \
# 0  The Perfect Red Velvet  Released: January 29, 2018Label: SM Entertainm...
#
#                                 Sales
# 0  KOR: 120,957[17]JPN: 12,799[A][12]

# %%
# Compilation Albums

title, detail, sale = column_values(10,11)

compilation_album = pd.DataFrame(list(zip(title, detail, sale)), columns=['Title', 'Details', 'Sales'])
compilation_album
# Out:
#                        Title  \
# 0  The ReVe Festival: Finale
#
#                                              Details  \
# 0  Released: December 23, 2019Label: SM Entertain...
#
#                                                Sales
# 0  KOR: 194,290[20]JPN: 7,442(Phy.)[21]JPN: 590(D...

# %%
# Extended Play

title, detail, sale = column_values(13,25)

extended_album = pd.DataFrame(list(zip(title, detail, sale)), columns=['Title', 'Details', 'Sales'])
extended_album
# Out:
#                        Title  \
# 0             Ice Cream Cake
# 1                 The Velvet
# 2           Russian Roulette
# 3                     Rookie
# 4             The Red Summer
# 5               Summer Magic
# 6                        RBB
# 7   The ReVe Festival: Day 1
# 8   The ReVe Festival: Day 2
# 9                   Queendom
# 10               #Cookie Jar
# 11                     Sappy
#
#                                               Details  \
# 0   Released: March 18, 2015Label: SM Entertainmen...
# 1   Released: March 17, 2016Label: SM Entertainmen...
# 2   Released: September 7, 2016Label: SM Entertain...
# 3   Released: February 1, 2017Label: SM Entertainm...
# 4   Released: July 10, 2017Label: SM Entertainment...
# 5   Released: August 6, 2018Label: SM Entertainmen...
# 6   Released: November 30, 2018Label: SM Entertain...
# 7   Released: June 19, 2019Label: SM Entertainment...
# 8   Released: August 20, 2019Label: SM Entertainme...
# 9   Released: August 16, 2021Label: SM Entertainme...
# 10  Released: July 4, 2018Label: Avex Trax, SM Ent...
# 11  Released: May 29, 2019Label: Avex Trax, SM Ent...
#
#                                                 Sales
# 0          KOR: 90,970[29]JPN: 2,796[30]US: 3,000[10]
# 1                       KOR: 56,944[31]JPN: 2,104[32]
# 2          KOR: 87,693[33]JPN: 3,446[34]US: 2,000[10]
# 3                      KOR: 118,747[35]JPN: 4,351[36]
# 4         KOR: 110,705[37]JPN: 4,659[38]US: 2,000[39]
# 5   KOR: 174,531[40]JPN: 8,004(Phy.)[41]JPN: 946(D...
# 6        KOR: 108,796[44]JPN: 5,411[45]US: 10,000[46]
# 7                      KOR: 193,669[47]JPN: 4,855[48]
# 8   KOR: 140,537[49]JPN: 3,960(Phy.)[50]JPN: 427(D...
# 9               KOR: 360,070[53]JPN: 12,452(Phy.)[54]
# 10                                    JPN: 31,638[56]
# 11                                    JPN: 17,236[57]

# %% [markdown]
# ### Chart DataFrame

# %%
# Names of the Columns
names_chart = data_1[1]

# %%
def chart_values(a, b):
    KOR_chart = []
    FRA_chart = []
    JPN_chart = []
    JPN_Hot_chart = []
    US_Heat_chart = []
    US_World_chart = []
    
    for i in range(a,b):
        if len(data_1[i]) <= 4:
            KOR_chart.append('—')
            FRA_chart.append('—')
            JPN_chart.append('—')
            JPN_Hot_chart.append('—')
            US_Heat_chart.append('—')
            US_World_chart.append('—')
        elif len(data_1[i]) == 9:
            KOR_chart.append(data_1[i][2])
            FRA_chart.append(data_1[i][3])
            JPN_chart.append(data_1[i][4])
            JPN_Hot_chart.append(data_1[i][5])
            US_Heat_chart.append(data_1[i][6])
            US_World_chart.append(data_1[i][7])
        elif len(data_1[i]) < 9:
            KOR_chart.append(data_1[i][2])
            FRA_chart.append('—')
            JPN_chart.append(data_1[i][3])
            JPN_Hot_chart.append(data_1[i][4])
            US_Heat_chart.append(data_1[i][5])
            US_World_chart.append(data_1[i][6])
        else:
            KOR_chart.append(data_1[i][2])
            FRA_chart.append(data_1[i][4])
            JPN_chart.append(data_1[i][5])
            JPN_Hot_chart.append(data_1[i][6])
            US_Heat_chart.append(data_1[i][8])
            US_World_chart.append(data_1[i][9])
    
    return KOR_chart, FRA_chart, JPN_chart, JPN_Hot_chart, US_Heat_chart, US_World_chart

# %%
# Studio ALbum Charts

kchart, fchart, jchart, j1chart, uchart, u1chart = chart_values(2,5)

studio_chart = pd.DataFrame(list(zip(kchart, fchart, jchart, j1chart, uchart, u1chart)), columns=names_chart)
studio_chart
# Out:
#   KOR[1] FRADig.[2] JPN[3] JPN Hot[4] US Heat.[5] US World[6]
# 0      1          —     47          —          24           1
# 1      2         95     20         52           3           1
# 2      —          —      —          —           —           —

# %%
# Reissue Album Charts
kchart, fchart, jchart, j1chart, uchart, u1chart = chart_values(7,8)

reissue_chart = pd.DataFrame(list(zip(kchart, fchart, jchart, j1chart, uchart, u1chart)), columns=names_chart)
reissue_chart
# Out:
#   KOR[1] FRADig.[2] JPN[3] JPN Hot[4] US Heat.[5] US World[6]
# 0      1         87     29         49           7           3

# %%
# Extended Play Charts
kchart, fchart, jchart, j1chart, uchart, u1chart = chart_values(13,25)
    
extended_chart = pd.DataFrame(list(zip(kchart, fchart, jchart, j1chart, uchart, u1chart)), columns=names_chart)
extended_chart
# Out:
#    KOR[1] FRADig.[2] JPN[3] JPN Hot[4] US Heat.[5] US World[6]
# 0       1          —     76          —          24           2
# 1       1          —     75          —           —           8
# 2       1        174     40          —          18           2
# 3       1          —     43          —          21           1
# 4       1        108     27          —           8           1
# 5       1         42     12         24           3           3
# 6       3         92     33         51           1           2
# 7       1         53     20         46           5           7
# 8       1         52     17         54          11           6
# 9       2          —     11         23          16          11
# 10      —          —      3          4           —          13
# 11      —          —      4          4           —           —
